# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("anshika2104/customer-shopping-data")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 109k/109k [00:00<00:00, 328kB/s]
# Extracting files...
# Path to dataset files: /Users/afif/.cache/kagglehub/datasets/anshika2104/customer-shopping-data/versions/1
